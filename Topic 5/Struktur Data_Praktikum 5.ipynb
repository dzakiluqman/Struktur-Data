# %%
def linear_search(arr, target):
  for i in range(len(arr)):
    if arr[i] == target:
      return i
  return -1

arr = [90, 27, 50, 20, 16, 29]
target = int(input("Masukkan 2 digit terakhir NPM Anda: "))

result = linear_search(arr, target)

if result != -1:
  print(f"Elemen ditemukan pada indeks {result}")
else:
  print("Elemen tidak ditemukan")
# Out:
# Masukkan 2 digit terakhir NPM Anda: 16
# Elemen ditemukan pada indeks 4

# %%
def binary_search(arr, target):
  low = 0
  high = len(arr) - 1

  while low <= high:
    mid = (low + high) // 2
    if arr[mid] == target:
      return mid
    elif arr[mid] < target:
      low = mid + 1
    else:
      high = mid - 1
  return -1

arr = [1111, 1212, 2009, 2208, 2705]

target = int(input("Masukkan tanggal lahir Anda (DDMM): "))

result = binary_search(arr, target)

if result != -1:
  print(f"Elemen ditemukan pada indeks {result}")
else:
  print("Elemen tidak ditemukan")
# Out:
# Masukkan tanggal lahir Anda (DDMM): 2705
# Elemen ditemukan pada indeks 4

# %%
import math

def jump_search(arr, target):
  n = len(arr)
  step = int(math.sqrt(n))
  prev = 0

  while prev < n and arr[min(step, n) - 1] < target:
    prev = step
    step += int(math.sqrt(n))
    if prev >= n:
      return -1

  for i in range(prev, min(step, n)):
    if arr[i].startswith(target):
      return i
  return -1

arr = ["Aldo", "Bayu", "Jono", "Rafi"]

target = input("Masukkan inisial nama Anda: ")

result = jump_search(arr, target)

if result != -1:
  print(f"Elemen ditemukan pada indeks {result}")
else:
  print("Elemen tidak ditemukan")
# Out:
# Masukkan inisial nama Anda: B
# Elemen ditemukan pada indeks 1
