# %%
# Ukuran Peta
size = int(input("Masukkan ukuran peta (n): "))

# Membuat peta dengan harta karun tersembunyi
treasure_map = ["_" for _ in range(size)]

# Tentukan lokasi harta karun secara manual
print(f"Selamat datang di Treasure Hunt! Peta memiliki {size} lokasi (0 hingga {size-1}).")
treasure_index = int(input(f"Masukkan lokasi harta karun (0 hingga {size-1}): "))

while treasure_index < 0 or treasure_index >= size:
    print("Masukkan angka dalam rentang yang benar!")
    treasure_index = int(input(f"Masukkan lokasi harta karun (0 hingga {size-1}): "))

# Menyembunyikan harta karun di lokasi yang dipilih
treasure_map[treasure_index] = "x"

# Fungsi untuk memulai permainan
def play_treasure_hunt():
    print("\nHarta karun telah disembunyikan! Sekarang giliran pemain menebak.")
    print("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")

    # Loop permainan
    while True:
        # Menampilkan peta tersembunyi kepada pemain (tanpa lokasi harta karun)
        print("\nPeta saat ini:", ["_" for _ in range(size)])

        # Input pemain
        try:
            guess = int(input(f"Masukkan tebakan Anda (0 hingga {size-1}): "))
        except ValueError:
            print("Masukkan angka yang valid!")
            continue

        # Validasi Input
        if guess < 0 or guess >= size:
            print("Indeks tidak valid, pilih antara 0 hingga", size-1)
            continue

        # Mengecek apakah tebakan benar
        if treasure_map[guess] == "x":
            print("Selamat! Anda berhasil menemukan harta karun!")
            break
        else:
            print("Tebakan Anda salah. Coba lagi!")

    print("Terima kasih sudah bermain!")

# Memulai permainan
play_treasure_hunt()
# Out:
# Masukkan ukuran peta (n): 1
# Selamat datang di Treasure Hunt! Peta memiliki 1 lokasi (0 hingga 0).
# Masukkan lokasi harta karun (0 hingga 0): 1
# Masukkan angka dalam rentang yang benar!
# Masukkan lokasi harta karun (0 hingga 0): 0
#
# Harta karun telah disembunyikan! Sekarang giliran pemain menebak.
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini: ['_']
# Masukkan tebakan Anda (0 hingga 0): 0
# Selamat! Anda berhasil menemukan harta karun!
# Terima kasih sudah bermain!

# %%
import random

# Ukuran Peta
size = int(input("Masukkan ukuran peta (n): "))

# Membuat peta dengan harta karun tersembunyi
treasure_map = ["_" for _ in range(size)]

# Tentukan lokasi harta karun secara otomatis
print(f"Selamat datang di Treasure Hunt! Peta memiliki {size} lokasi (0 hingga {size-1}).")
treasure_index = random.randint(0, size)

# Menyembunyikan harta karun di lokasi yang diacak
treasure_map[treasure_index] = "x"

# Fungsi untuk memulai permainan
def play_treasure_hunt():
    print("\nHarta karun telah disembunyikan! Sekarang giliran pemain menebak.")
    print("Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.")

    # Loop permainan
    while True:
        # Menampilkan peta tersembunyi kepada pemain (tanpa lokasi harta karun)
        print("\nPeta saat ini:", ["_" for _ in range(size)])

        # Input pemain
        try:
            guess = int(input(f"Masukkan tebakan Anda (0 hingga {size-1}): "))
        except ValueError:
            print("Masukkan angka yang valid!")
            continue

        # Validasi Input
        if guess < 0 or guess >= size:
            print("Indeks tidak valid, pilih antara 0 hingga", size-1)
            continue

        # Mengecek apakah tebakan benar
        if treasure_map[guess] == "x":
            print("Selamat! Anda berhasil menemukan harta karun!")
            break
        else:
            print("Tebakan Anda salah. Coba lagi!")

    print("Terima kasih sudah bermain!")

# Memulai permainan
play_treasure_hunt()
# Out:
# Masukkan ukuran peta (n): 10
# Selamat datang di Treasure Hunt! Peta memiliki 10 lokasi (0 hingga 9).
#
# Harta karun telah disembunyikan! Sekarang giliran pemain menebak.
# Cobalah untuk menemukan harta karun dengan menebak indeks yang benar.
#
# Peta saat ini: ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan tebakan Anda (0 hingga 9): 9
# Tebakan Anda salah. Coba lagi!
#
# Peta saat ini: ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan tebakan Anda (0 hingga 9): 8
# Tebakan Anda salah. Coba lagi!
#
# Peta saat ini: ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan tebakan Anda (0 hingga 9): 7
# Tebakan Anda salah. Coba lagi!
#
# Peta saat ini: ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan tebakan Anda (0 hingga 9): 6
# Tebakan Anda salah. Coba lagi!
#
# Peta saat ini: ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan tebakan Anda (0 hingga 9): 5
# Tebakan Anda salah. Coba lagi!
#
# Peta saat ini: ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']
# Masukkan tebakan Anda (0 hingga 9): 4
# Selamat! Anda berhasil menemukan harta karun!
# Terima kasih sudah bermain!
